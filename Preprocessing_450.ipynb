# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2e03fb92-3c6f-49f5-8a7a-679eaaea96e8" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2e03fb92-3c6f-49f5-8a7a-679eaaea96e8">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %%
all_stocks_5yr = pd.read_csv('all_stocks_5yr.csv')

# %%
all_stocks_5yr
# Out:
#               date   open   high    low  close    volume Name
# 0       2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1       2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2       2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3       2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4       2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...            ...    ...    ...    ...    ...       ...  ...
# 619035  2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036  2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037  2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038  2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039  2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619040 rows x 7 columns]

# %%
all_stocks_5yr = all_stocks_5yr.dropna()

# %%
all_stocks_5yr['date'] = pd.to_datetime(all_stocks_5yr['date'])
# Out:
# <ipython-input-6-392265a1c7e6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_stocks_5yr['date'] = pd.to_datetime(all_stocks_5yr['date'])

# %%
all_stocks_5yr.dtypes
# Out:
# date      datetime64[ns]
# open             float64
# high             float64
# low              float64
# close            float64
# volume             int64
# Name              object
# dtype: object

# %%
indexProcessed = pd.read_csv('indexProcessed.csv')

# %%
indexProcessed
# Out:
#           Index        Date          Open          High           Low  \
# 0           HSI  1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI  1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI  1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI  1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI  1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...         ...           ...           ...           ...
# 104219  J203.JO  2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO  2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO  2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO  2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO  2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049     0.0   333.879006
# ...

# %%
indexProcessed.dropna()
# Out:
#           Index        Date          Open          High           Low  \
# 0           HSI  1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI  1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI  1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI  1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI  1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...         ...           ...           ...           ...
# 104219  J203.JO  2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO  2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO  2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO  2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO  2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049     0.0   333.879006
# ...

# %%
indexProcessed['Date'] = pd.to_datetime(indexProcessed['Date'])

# %%
indexProcessed['Volume'] = indexProcessed['Volume'].astype(int)

# %%
indexProcessed.dtypes
# Out:
# Index                object
# Date         datetime64[ns]
# Open                float64
# High                float64
# Low                 float64
# Close               float64
# Adj Close           float64
# Volume                int64
# CloseUSD            float64
# dtype: object

# %%
indexProcessed
# Out:
#           Index       Date          Open          High           Low  \
# 0           HSI 1986-12-31   2568.300049   2568.300049   2568.300049
# 1           HSI 1987-01-02   2540.100098   2540.100098   2540.100098
# 2           HSI 1987-01-05   2552.399902   2552.399902   2552.399902
# 3           HSI 1987-01-06   2583.899902   2583.899902   2583.899902
# 4           HSI 1987-01-07   2607.100098   2607.100098   2607.100098
# ...         ...        ...           ...           ...           ...
# 104219  J203.JO 2021-05-25  66054.921880  66812.453130  66022.976560
# 104220  J203.JO 2021-05-26  66076.679690  66446.367190  66030.351560
# 104221  J203.JO 2021-05-27  66108.226560  66940.250000  66102.546880
# 104222  J203.JO 2021-05-28  66940.250000  67726.562500  66794.609380
# 104223  J203.JO 2021-05-31  67554.859380  68140.851560  67554.859380
#
#                Close     Adj Close  Volume     CloseUSD
# 0        2568.300049   2568.300049       0   333.879006
# ...

# %%
indexProcessed.rename(columns={'Index': 'marketIndex', 'Date': 'date', 'Open': 'open',
                               'High': 'high', 'Low': 'low', 'Close': 'close',
                               'Adj Close': 'adjClose', 'Volume': 'volume', 'CloseUSD': 'closeUSD'}, inplace=True)

# %%
indexProcessed
# Out:
#        marketIndex       date          open          high           low  \
# 0              HSI 1986-12-31   2568.300049   2568.300049   2568.300049
# 1              HSI 1987-01-02   2540.100098   2540.100098   2540.100098
# 2              HSI 1987-01-05   2552.399902   2552.399902   2552.399902
# 3              HSI 1987-01-06   2583.899902   2583.899902   2583.899902
# 4              HSI 1987-01-07   2607.100098   2607.100098   2607.100098
# ...            ...        ...           ...           ...           ...
# 104219     J203.JO 2021-05-25  66054.921880  66812.453130  66022.976560
# 104220     J203.JO 2021-05-26  66076.679690  66446.367190  66030.351560
# 104221     J203.JO 2021-05-27  66108.226560  66940.250000  66102.546880
# 104222     J203.JO 2021-05-28  66940.250000  67726.562500  66794.609380
# 104223     J203.JO 2021-05-31  67554.859380  68140.851560  67554.859380
#
#                close      adjClose  volume     closeUSD
# ...

# %%
all_stocks_5yr.rename(columns={'Name': 'name'}, inplace=True)
# Out:
# <ipython-input-18-b2494f834e24>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_stocks_5yr.rename(columns={'Name': 'name'}, inplace=True)

# %%
all_stocks_5yr
# Out:
#              date   open   high    low  close    volume name
# 0      2013-02-08  15.07  15.12  14.63  14.75   8407500  AAL
# 1      2013-02-11  14.89  15.01  14.26  14.46   8882000  AAL
# 2      2013-02-12  14.45  14.51  14.10  14.27   8126000  AAL
# 3      2013-02-13  14.30  14.94  14.25  14.66  10259500  AAL
# 4      2013-02-14  14.94  14.96  13.16  13.99  31879900  AAL
# ...           ...    ...    ...    ...    ...       ...  ...
# 619035 2018-02-01  76.84  78.27  76.69  77.82   2982259  ZTS
# 619036 2018-02-02  77.53  78.12  76.73  76.78   2595187  ZTS
# 619037 2018-02-05  76.64  76.92  73.18  73.83   2962031  ZTS
# 619038 2018-02-06  72.74  74.56  72.13  73.27   4924323  ZTS
# 619039 2018-02-07  72.70  75.00  72.69  73.86   4534912  ZTS
#
# [619029 rows x 7 columns]

# %%
all_stocks_5yr.to_csv('stocks.csv', index=False)
indexProcessed.to_csv('markets.csv', index=False)

# %%
files.download('stocks.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-21-b6a3831ecdf7> in <cell line: 2>()
#       1 files.download('stocks.csv')
# ----> 2 files.download('indexes.csv')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/files.py in download(filename)
#     223   if not _os.path.exists(filename):
#     224     msg = 'Cannot find file: {}'.format(filename)
# --> 225     raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     226
#     227   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: indexes.csv

# %%
files.download('markets.csv')

# %%
date = all_stocks_5yr[['date']]

# %%
date.dtypes
# Out:
# date    datetime64[ns]
# dtype: object

# %%
date.to_csv('date.csv', index=False)
files.download('date.csv')

# %%
markets = pd.read_csv('markets.csv')

# %%
markets
# Out:
#        marketIndex        date          open          high           low  \
# 0              HSI  1986-12-31   2568.300049   2568.300049   2568.300049
# 1              HSI  1987-01-02   2540.100098   2540.100098   2540.100098
# 2              HSI  1987-01-05   2552.399902   2552.399902   2552.399902
# 3              HSI  1987-01-06   2583.899902   2583.899902   2583.899902
# 4              HSI  1987-01-07   2607.100098   2607.100098   2607.100098
# ...            ...         ...           ...           ...           ...
# 104219     J203.JO  2021-05-25  66054.921880  66812.453130  66022.976560
# 104220     J203.JO  2021-05-26  66076.679690  66446.367190  66030.351560
# 104221     J203.JO  2021-05-27  66108.226560  66940.250000  66102.546880
# 104222     J203.JO  2021-05-28  66940.250000  67726.562500  66794.609380
# 104223     J203.JO  2021-05-31  67554.859380  68140.851560  67554.859380
#
#                close      adjClose  volume     closeUSD
# ...

# %%
markets['date'] = pd.to_datetime(markets['date'])

# %%
markets.dtypes
# Out:
# marketIndex            object
# date           datetime64[ns]
# open                  float64
# high                  float64
# low                   float64
# close                 float64
# adjClose              float64
# volume                  int64
# closeUSD              float64
# dtype: object

# %%
markets['volume'].max()
# Out:
# 94403740000

# %%
stocks = pd.read_csv('stocks.csv')

# %%
stocks.dtypes
# Out:
# date       object
# open      float64
# high      float64
# low       float64
# close     float64
# volume      int64
# name       object
# dtype: object
